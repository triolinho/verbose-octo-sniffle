# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
pip install jupyter-dash
# Out:
# ...
#      |████████████████████████████████| 45 kB 1.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 66 kB 2.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 94 kB 2.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 6.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.4 MB 16.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 187 kB 17.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.8 MB 13.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 796 kB 4.4 MB/s eta 0:00:01
# ...
#   Created wheel for ansi2html: filename=ansi2html-1.5.2-py3-none-any.whl size=13860 sha256=aafdf121ee57e43cca8c42be1b65f68d0628700706bc1b07d3b46638105e6c0f
#   Stored in directory: /Users/andrewtriola/Library/Caches/pip/wheels/62/fa/1e/1ad9fb5c2225613adfcf012dd25f313f3a065f2131cdff0a99
# ...
#   Created wheel for dash: filename=dash-1.12.0-py3-none-any.whl size=73891 sha256=dbb2f5d98ad8a6fd5950caa36a0cdcd059163f9e481c3f4a74bfd9971ec54998
# ...

# %%
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
# Load Data
df = px.data.tips()
# Build App
app = JupyterDash(__name__)
app.layout = html.Div([
    html.H1("JupyterDash Demo"),
    dcc.Graph(id='graph'),
    html.Label([
        "colorscale",
        dcc.Dropdown(
            id='colorscale-dropdown', clearable=False,
            value='plasma', options=[
                {'label': c, 'value': c}
                for c in px.colors.named_colorscales()
            ])
    ]),
])
# Define callback to update graph
@app.callback(
    Output('graph', 'figure'),
    [Input("colorscale-dropdown", "value")]
)
def update_figure(colorscale):
    return px.scatter(
        df, x="total_bill", y="tip", color="size",
        color_continuous_scale=colorscale,
        render_mode="webgl", title="Tips"
    )
# Run app and display result inline in the notebook
app.run_server(mode='inline')
# Out:
#         <iframe
#             width="800"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import numpy as np

# %%
fd_1 = pd.read_csv("fd_1.csv", index_col=0)

# %%
fd_1.head()
# Out:
#             Sport     Date                                     Title  \
# Entry Id
# S2014268241   nba  3/11/20  $4_000 Pro Monthly FDP Loyalty Free Play
# S2014175433   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)
# S2014175293   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)
# S2014175208   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)
# S2014175131   nba  3/11/20    50/50 League ($2 - Top 50% Win) (Main)
#
#             SalaryCap  Score  Opp Score  Position  Entries    Opponent  \
# Entry Id
# S2014268241      $60k  337.5        NaN       100   5092.0  Tournament
# S2014175433      $60k  337.5        NaN         7    100.0  Tournament
# S2014175293      $60k  337.5        NaN         6    100.0  Tournament
# S2014175208      $60k  337.5        NaN         8    100.0  Tournament
# S2014175131      $60k  337.5        NaN         6    100.0  Tournament
#
#              Entry ($)  Winnings ($)                                     Link  \
# Entry Id
# ...

# %%
fd_2 = pd.read_csv("fd_2.csv", index_col=0)

# %%
fd_2.head()
# Out:
#             Sport      Date                                   Title SalaryCap  \
# Entry Id
# S1942104080   nba  12/31/19  50/50 League ($2 - Top 50% Win) (Main)      $60k
# S1942103945   nba  12/31/19  50/50 League ($2 - Top 50% Win) (Main)      $60k
# S1942103849   nba  12/31/19  50/50 League ($2 - Top 50% Win) (Main)      $60k
# S1942103710   nba  12/31/19  50/50 League ($2 - Top 50% Win) (Main)      $60k
# S1942103444   nba  12/31/19  50/50 League ($2 - Top 50% Win) (Main)      $60k
#
#              Score  Opp Score  Position  Entries    Opponent  Entry ($)  \
# Entry Id
# S1942104080  325.0        NaN        42      100  Tournament        2.0
# S1942103945  325.0        NaN        45      100  Tournament        2.0
# S1942103849  325.0        NaN        42      100  Tournament        2.0
# S1942103710  325.0        NaN        44      100  Tournament        2.0
# S1942103444  325.0        NaN        48      100  Tournament        2.0
#
# ...

# %%
fd_3 = pd.read_csv("fd_3.csv", index_col=0)

# %%
fd_3.head()
# Out:
#             Sport      Date                                    Title  \
# Entry Id
# S1898583940   epl  11/30/19                       $100 Wonder Strike
# S1898538782   nfl   12/1/19  50/50 Contest ($2 - Top 50% Win) (Main)
# S1898538731   nfl   12/1/19  50/50 Contest ($1 - Top 50% Win) (Main)
# S1898538670   nfl   12/1/19  50/50 Contest ($2 - Top 50% Win) (Main)
# S1898538626   nfl   12/1/19  50/50 Contest ($1 - Top 50% Win) (Main)
#
#             SalaryCap  Score  Opp Score  Position  Entries    Opponent  \
# Entry Id
# S1898583940       $0k   74.4        NaN        34       40  Tournament
# S1898538782      $60k  139.4        NaN        27      100  Tournament
# S1898538731      $60k  139.4        NaN        22      100  Tournament
# S1898538670      $60k  139.4        NaN        24      100  Tournament
# S1898538626      $60k  139.4        NaN        25      100  Tournament
#
#              Entry ($)  Winnings ($)                                     Link
# Entry Id
# ...

# %%
fd_4 = pd.read_csv("fd_4.csv", index_col=0)

# %%
fd_4.head()
# Out:
#             Sport     Date                                   Title SalaryCap  \
# Entry Id
# S1862702827   nba  11/5/19  50/50 League ($1 - Top 50% Win) (Main)      $60k
# S1862702761   nba  11/5/19  50/50 League ($1 - Top 50% Win) (Main)      $60k
# S1862639831   nba  11/5/19       $10K Tue NBA Swat (3 Entries Max)      $60k
# S1862639836   nba  11/5/19       $10K Tue NBA Swat (3 Entries Max)      $60k
# S1862639840   nba  11/5/19       $10K Tue NBA Swat (3 Entries Max)      $60k
#
#              Score  Opp Score  Position  Entries    Opponent  Entry ($)  \
# Entry Id
# S1862702827  337.6        NaN         3      100  Tournament        1.0
# S1862702761  337.6        NaN         3      100  Tournament        1.0
# S1862639831  267.2        NaN      6598    11904  Tournament        1.0
# S1862639836  283.4        NaN      4309    11904  Tournament        1.0
# S1862639840  207.2        NaN     11684    11904  Tournament        1.0
#
# ...

# %%
fd_5 = pd.read_csv("fd_5.csv", index_col=0)

# %%
fd_5.head()
# Out:
#             Sport     Date                                          Title  \
# Entry Id
# S1249194147   mlb  8/14/17              $11K Mon MLB Bunt (Single Entry)
# S1249194115   mlb  8/14/17  $1K Toughest Ticket Contest presented by Ford
# S1249193638   nfl  8/17/17    $2K Thu NFL Preseason Safety (Single Entry)
# S1248961928   mlb  8/13/17           $10K Sun MLB Sac Fly (3 Entries Max)
# S1248961929   mlb  8/13/17           $10K Sun MLB Sac Fly (3 Entries Max)
#
#             SalaryCap   Score  Opp Score  Position  Entries    Opponent  \
# Entry Id
# S1249194147      $35k   94.90        NaN     10054    12941  Tournament
# S1249194115      $35k   94.90        NaN     21369    27465  Tournament
# S1249193638      $60k   23.66        NaN      1126     1176  Tournament
# S1248961928      $35k  119.90        NaN      7723    11764  Tournament
# S1248961929      $35k  119.90        NaN      7723    11764  Tournament
#
# ...

# %%
fd_6 = pd.read_csv("fd_6.csv", index_col=0)

# %%
fd_6.head()
# Out:
#             Sport      Date                                     Title  \
# Entry Id
# S1564284279   nfl  10/21/18                Covers Championship Series
# S1563136984   nfl  10/21/18  50/50 Contest ($25 - Top 50% Win) (Main)
# S1563136851   nfl  10/21/18  50/50 Contest ($25 - Top 50% Win) (Main)
# S1563085548   nfl  10/21/18      $50K Sun NFL Scramble (Single Entry)
# S1561321196   cfb  10/20/18                   $10K Sat CFB Fight Song
#
#             SalaryCap   Score  Opp Score  Position Entries    Opponent  \
# Entry Id
# S1564284279      $60k  119.00        NaN    7027.0   16095  Tournament
# S1563136984      $60k  112.18        NaN      78.0     100  Tournament
# S1563136851      $60k  112.18        NaN      72.0     100  Tournament
# S1563085548      $60k  112.18        NaN    3607.0    5882  Tournament
# S1561321196      $60k  137.12        NaN     182.0    1621  Tournament
#
#              Entry ($) Winnings ($)                                     Link
# Entry Id
# ...

# %%
fd_7 = pd.read_csv("fd_7.csv", index_col=0)

# %%
fd_7.head()
# Out:
#             Sport     Date                                            Title  \
# Entry Id
# S1204936442   mlb  4/22/17             $10K Sat MLB Sac Fly (3 Entries Max)
# S1204936436   mlb  4/22/17             $10K Sat MLB Sac Fly (3 Entries Max)
# S1204936319   mlb  4/22/17                  $8K Sat MLB Bunt (Single Entry)
# S1204935153   mlb  4/22/17  $5K Sat MLB Sac Fly (3 Entries Max_ Early Only)
# S1204935154   mlb  4/22/17  $5K Sat MLB Sac Fly (3 Entries Max_ Early Only)
#
#             SalaryCap  Score  Opp Score  Position Entries    Opponent  \
# Entry Id
# S1204936442      $35k  125.8        NaN    6242.0   11764  Tournament
# S1204936436      $35k  137.4        NaN    4672.0   11764  Tournament
# S1204936319      $35k  130.9        NaN    4494.0    9411  Tournament
# S1204935153      $35k   74.9        NaN    5796.0    5882  Tournament
# S1204935154      $35k  137.0        NaN    2794.0    5882  Tournament
#
# ...

# %%
fd_8 = pd.read_csv("fd_8.csv", index_col=0)

# %%
fd_8.head()
# Out:
#            Sport    Date                                              Title  \
# Entry Id
# S457341279   nba  4/6/16  $10K NBA / MLB 3-Day Cross-Sport Survivor Round 3
# S457341283   nba  4/6/16  $10K NBA / MLB 3-Day Cross-Sport Survivor Round 3
# S457341285   nba  4/6/16  $10K NBA / MLB 3-Day Cross-Sport Survivor Round 3
# S457341286   nba  4/6/16  $10K NBA / MLB 3-Day Cross-Sport Survivor Round 3
# S457336380   nba  4/6/16   $5K NBA / MLB 3-Day Cross-Sport Survivor Round 3
#
#            SalaryCap  Score  Opp Score  Position  Entries    Opponent  \
# Entry Id
# S457341279      $60k  272.2        NaN       942     2104  Tournament
# S457341283      $60k  272.2        NaN       942     2104  Tournament
# S457341285      $60k  272.2        NaN       942     2104  Tournament
# S457341286      $60k  272.2        NaN       942     2104  Tournament
# S457336380      $60k  272.2        NaN       413     1028  Tournament
#
# ...

# %%
fd_9 = pd.read_csv("fd_9.csv", index_col=0)

# %%
fd_9.head()
# Out:
#             Sport      Date                                 Title SalaryCap  \
# Entry Id
# S1115774069   nba  12/18/16  $18K Sun NBA Dribbler (Single Entry)      $60k
# S1114883251   nba  12/17/16                 The streak had ended!      $60k
# S1114794971   epl  12/18/16  $3K Sun EPL Sweeper ($3K Guaranteed)      $60k
# S1114771845   epl  12/17/16               EPL Head-to-head (Main)      $60k
# S1114685030   nba  12/17/16     $15K Sat NBA Block (Single Entry)      $60k
#
#               Score  Opp Score  Position Entries         Opponent  Entry ($)  \
# Entry Id
# S1115774069  275.90        NaN    1786.0   19567       Tournament          1
# S1114883251  316.20        NaN       1.0       4  4 player league          5
# S1114794971  199.25        NaN       7.0    1176       Tournament          3
# S1114771845  164.25      180.0       2.0       2         nwalker2          5
# S1114685030  316.20        NaN     855.0    8676       Tournament          2
#
# ...

# %%
fd_10 = pd.read_csv("fd_10.csv", index_col=0)

# %%
fd_10.head()
# Out:
#             Sport     Date                                              Title  \
# Entry Id
# S1473574606   mlb  5/31/18                $3K Thu MLB Sac Fly (3 Entries Max)
# S1473574490   mlb  5/31/18  $8K Thu MLB Bunt (Single Entry_ Next Fan Up Ch...
# S1473107849   mlb  5/30/18             $8K Wed MLB Stolen Base (Single Entry)
# S1473107834   mlb  5/30/18                $5K Wed MLB Sac Fly (3 Entries Max)
# S1473107835   mlb  5/30/18                $5K Wed MLB Sac Fly (3 Entries Max)
#
#             SalaryCap  Score  Opp Score  Position Entries    Opponent  \
# Entry Id
# S1473574606      $35k   48.0        NaN    3490.0    3571  Tournament
# S1473574490      $35k  169.3        NaN    1101.0    9523  Tournament
# S1473107849      $35k  144.1        NaN     630.0    4761  Tournament
# S1473107834      $35k  111.3        NaN    2829.0    5952  Tournament
# S1473107835      $35k  107.5        NaN    3096.0    5952  Tournament
#
# ...

# %%
fd_11 = pd.read_csv("fd_11.csv", index_col=0)

# %%
fd_11.head()
# Out:
#             Sport     Date                                     Title  \
# Entry Id
# S1798834924   mlb  9/19/19                    $250 MLB Small Sac Fly
# S1798834920   mlb  9/19/19                    $250 MLB Small Sac Fly
# S1798834843   mlb  9/19/19  $1500 Thu MLB Stolen Base (Single Entry)
# S1798834784   mlb  9/19/19           $2K Thu MLB Bunt (Single Entry)
# S1798340170   mlb  9/18/19   50/50 Contest ($5 - Top 50% Win) (Main)
#
#             SalaryCap  Score  Opp Score  Position  Entries    Opponent  \
# Entry Id
# S1798834924      $35k   77.1        NaN       277      297  Tournament
# S1798834920      $35k   91.3        NaN       240      297  Tournament
# S1798834843      $35k   94.3        NaN       778      892  Tournament
# S1798834784      $35k  118.3        NaN      1458     2380  Tournament
# S1798340170      $35k  120.3        NaN        25      100  Tournament
#
#              Entry ($)  Winnings ($)                                     Link
# Entry Id
# ...

# %%
fd_12 = pd.read_csv("fd_12.csv", index_col=0)

# %%
fd_12.head()
# Out:
#             Sport     Date                                 Title SalaryCap  \
# Entry Id
# S1688306979   nba  2/27/19     $16K Wed NBA Block (Single Entry)      $60k
# S1688306912   nba  2/27/19  $17K Wed NBA Dribbler (Single Entry)      $60k
# S1687835269   nba  2/26/19     $13K Tue NBA Block (Single Entry)      $60k
# S1687835260   nba  2/26/19      $8K Tue NBA Swat (3 Entries Max)      $60k
# S1687835261   nba  2/26/19      $8K Tue NBA Swat (3 Entries Max)      $60k
#
#              Score  Opp Score  Position  Entries    Opponent  Entry ($)  \
# Entry Id
# S1688306979  278.5        NaN      5728     9523  Tournament        2.0
# S1688306912  278.5        NaN     11981    20238  Tournament        1.0
# S1687835269  252.9        NaN      2717     7738  Tournament        2.0
# S1687835260  242.7        NaN      4611     9523  Tournament        1.0
# S1687835261  252.9        NaN      3453     9523  Tournament        1.0
#
# ...

# %%
fd_13 = pd.read_csv("fd_13.csv", index_col=0)

# %%
fd_13.head()
# Out:
#             Sport      Date                                 Title SalaryCap  \
# Entry Id
# S1370462608   nfl  12/31/17     My Loser Friends (NFL Contest 14)      $60k
# S1370462396   nfl  12/31/17  First World Problem (NFL Contest 17)      $60k
# S1370365731   nba  12/27/17     $17K Wed NBA Block (Single Entry)      $60k
# S1370365709   nba  12/27/17     $10K Wed NBA Swat (3 Entries Max)      $60k
# S1370365711   nba  12/27/17     $10K Wed NBA Swat (3 Entries Max)      $60k
#
#               Score  Opp Score  Position Entries         Opponent  Entry ($)  \
# Entry Id
# S1370462608   91.10        NaN       4.0       5  5 player league          2
# S1370462396   74.76        NaN       9.0       9  9 player league          5
# S1370365731  279.40        NaN    5181.0   10119       Tournament          2
# S1370365709  300.50        NaN    3091.0   11904       Tournament          1
# S1370365711  310.40        NaN    1936.0   11904       Tournament          1
#
# ...

# %%
fd_14 = pd.read_csv("fd_14.csv", index_col=0)

# %%
fd_14.head()
# Out:
#             Sport     Date                                        Title  \
# Entry Id
# S1025976874   nfl  9/22/16  50/50 Contest ($10 - Top 50% Win) (Thu-Mon)
# S1025665013   nfl  9/25/16             Jacksonville Sportsrich Showdown
# S1025578379   mlb  9/22/16       $8K Thu MLB Stolen Base (Single Entry)
# S1025578140   mlb  9/22/16             $10K Thu MLB Bunt (Single Entry)
# S1025271093   nfl  9/25/16                My Loser Friends (NFL Week 3)
#
#             SalaryCap   Score  Opp Score  Position  Entries         Opponent  \
# Entry Id
# S1025976874      $60k   85.80        NaN        80      100       Tournament
# S1025665013      $60k   74.86        NaN      1145     1335       Tournament
# S1025578379      $35k   76.40        NaN      4206     4624       Tournament
# S1025578140      $35k   63.40        NaN     11040    11560       Tournament
# S1025271093      $60k  109.98        NaN         5        8  8 player league
#
# ...

# %%
fd_df = pd.read_csv("fd_df.csv", index_col=0)

# %%
fd_df.head()
# Out:
#                    Date   Score   Entries  Entry  Winnings  Profit Sport  \
# Entry Id
# S1124007655  2017-01-01  135.20    5042.0    7.0       0.0    -7.0   nfl
# S1129890321  2017-01-01   82.88  110080.0    2.0       0.0    -2.0   nfl
# S1129826425  2017-01-01  111.50       4.0    5.0       0.0    -5.0   nfl
# S1129544973  2017-01-01   97.00    4705.0    1.0       0.0    -1.0   nfl
# S1129520203  2017-01-01  300.50       5.0    5.0       0.0    -5.0   nba
#
#                 Type
# Entry Id
# S1124007655  tourney
# S1129890321  tourney
# S1129826425  tourney
# S1129544973  tourney
# S1129520203  tourney

# %%
fd_1.columns
# Out:
# Index(['Sport', 'Date', 'Title', 'SalaryCap', 'Score', 'Opp Score', 'Position',
#        'Entries', 'Opponent', 'Entry ($)', 'Winnings ($)', 'Link',
#        'Unnamed: 13'],
#       dtype='object')

# %%
frames = [fd_1, fd_2, fd_3, fd_4, fd_5, fd_6, fd_7, fd_8, fd_9, fd_10, fd_11, fd_12, fd_13, fd_14]

# %%
result = pd.concat(frames)

# %%
result.head()
# Out:
#             Sport     Date                                     Title  \
# Entry Id
# S2014268241   nba  3/11/20  $4_000 Pro Monthly FDP Loyalty Free Play
# S2014175433   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)
# S2014175293   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)
# S2014175208   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)
# S2014175131   nba  3/11/20    50/50 League ($2 - Top 50% Win) (Main)
#
#             SalaryCap  Score  Opp Score  Position Entries    Opponent  \
# Entry Id
# S2014268241      $60k  337.5        NaN     100.0    5092  Tournament
# S2014175433      $60k  337.5        NaN       7.0     100  Tournament
# S2014175293      $60k  337.5        NaN       6.0     100  Tournament
# S2014175208      $60k  337.5        NaN       8.0     100  Tournament
# S2014175131      $60k  337.5        NaN       6.0     100  Tournament
#
#              Entry ($) Winnings ($)                                     Link  \
# Entry Id
# ...

# %%
col_list = ['Sport', 'Date', 'Title', 'Score', 'Position', 'Entries', 'Entry ($)', 'Winnings ($)']

# %%
col_list_2 = ['Sport', 'Date', 'Title', 'Score', 'Position', 'Opponent', 'Entry ($)', 'Winnings ($)']

# %%
fd_df = result[col_list].copy()

# %%
fd_df_opp = result[col_list_2].copy()

# %%
fd_df_opp.head()
# Out:
#             Sport     Date                                     Title  Score  \
# Entry Id
# S2014268241   nba  3/11/20  $4_000 Pro Monthly FDP Loyalty Free Play  337.5
# S2014175433   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175293   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175208   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175131   nba  3/11/20    50/50 League ($2 - Top 50% Win) (Main)  337.5
#
#              Position    Opponent  Entry ($) Winnings ($)
# Entry Id
# S2014268241     100.0  Tournament        0.0            8
# S2014175433       7.0  Tournament        1.0          1.8
# S2014175293       6.0  Tournament        1.0          1.8
# S2014175208       8.0  Tournament        1.0          1.8
# S2014175131       6.0  Tournament        2.0          3.6

# %%
fd_df_opp[fd_df_opp['Opponent'] == 'nwalker2']
# Out:
#             Sport      Date                         Title   Score  Position  \
# Entry Id
# S1220688480   epl   5/21/17       EPL Head-to-head (Main)  167.50       2.0
# S1517430973   nfl    9/9/18       NFL Head-to-head (Main)  176.04       1.0
# S1190341524   epl    4/1/17       EPL Head-to-head (Main)  154.00       1.0
# S1178251245   nba   3/11/17       NBA Head-to-head (Main)  283.10       1.0
# S1175625350   nba    3/7/17       NBA Head-to-head (Main)  253.50       2.0
# S1171615025   epl    3/4/17       EPL Head-to-head (Main)  200.75       1.0
# S1164496369   ucl   2/14/17       UCL Head-to-head (Main)  109.50       1.0
# S1162108711   epl   2/11/17       EPL Head-to-head (Main)  177.50       2.0
# S1157782036   epl    2/4/17       EPL Head-to-head (Main)  117.50       2.0
# S1147526307   epl   1/21/17       EPL Head-to-head (Main)  113.25       2.0
# S1141408877   epl   1/14/17       EPL Head-to-head (Main)  153.25       1.0
# ...

# %%
fd_df = fd_df.dropna()

# %%
fd_df_opp = fd_df_opp.dropna()

# %%
fd_df.shape
# Out:
# (13700, 7)

# %%
fd_df.head()
# Out:
#             Sport     Date                                     Title  Score  \
# Entry Id
# S2014268241   nba  3/11/20  $4_000 Pro Monthly FDP Loyalty Free Play  337.5
# S2014175433   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175293   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175208   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175131   nba  3/11/20    50/50 League ($2 - Top 50% Win) (Main)  337.5
#
#              Position Entries  Entry ($) Winnings ($)
# Entry Id
# S2014268241     100.0    5092        0.0            8
# S2014175433       7.0     100        1.0          1.8
# S2014175293       6.0     100        1.0          1.8
# S2014175208       8.0     100        1.0          1.8
# S2014175131       6.0     100        2.0          3.6

# %%
fd_df.to_csv(r'/Users/andrewtriola/Documents/flatiron/fd_project/verbose-octo-sniffle/fd_df.csv')

# %%
fd_df = fd_df.rename(columns={"Entry ($)": "Entry", "Winnings ($)": "Winnings"})

# %%
fd_df_opp = fd_df_opp.rename(columns={"Entry ($)": "Entry", "Winnings ($)": "Winnings"})

# %%
fd_df_opp.head()
# Out:
#             Sport     Date                                     Title  Score  \
# Entry Id
# S2014268241   nba  3/11/20  $4_000 Pro Monthly FDP Loyalty Free Play  337.5
# S2014175433   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175293   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175208   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175131   nba  3/11/20    50/50 League ($2 - Top 50% Win) (Main)  337.5
#
#              Position    Opponent  Entry Winnings
# Entry Id
# S2014268241     100.0  Tournament    0.0        8
# S2014175433       7.0  Tournament    1.0      1.8
# S2014175293       6.0  Tournament    1.0      1.8
# S2014175208       8.0  Tournament    1.0      1.8
# S2014175131       6.0  Tournament    2.0      3.6

# %%
fd_df.head()
# Out:
#                   Date   Score   Entries  Entry Winnings Sport     Type
# Entry Id
# S1124007655 2017-01-01  135.20    5042.0    7.0        0   nfl  tourney
# S1129890321 2017-01-01   82.88  110080.0    2.0        0   nfl  tourney
# S1129826425 2017-01-01  111.50       4.0    5.0        0   nfl  tourney
# S1129544973 2017-01-01   97.00    4705.0    1.0        0   nfl  tourney
# S1129520203 2017-01-01  300.50       5.0    5.0        0   nba  tourney

# %%
fd_df = fd_df.sort_values(by='Date')

# %%
fd_df.Date = pd.to_datetime(fd_df.Date, infer_datetime_format=True)

# %%
fd_df_opp.Date = pd.to_datetime(fd_df_opp.Date, infer_datetime_format=True)
# Out:
# /Users/andrewtriola/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fd_df.head()
# Out:
#             Sport       Date                                        Title  \
# Entry Id
# S1124007655   nfl 2017-01-01    $30K Sun NFL Flea Flicker (5 Entries Max)
# S1129890321   nfl 2017-01-01  $250K Sun NFL Snap ($25K to 1st_ 1pm Only)
# S1129826425   nfl 2017-01-01                       Wanted to include Gary
# S1129544973   nfl 2017-01-01                        $4K Sun NFL Mini Dive
# S1129520203   nba 2017-01-01                         NBA on New Years Day
#
#               Score  Position Entries  Entry ($) Winnings ($)
# Entry Id
# S1124007655  135.20    1053.0    5042        7.0            0
# S1129890321   82.88   83864.0  110080        2.0            0
# S1129826425  111.50       3.0       4        5.0            0
# S1129544973   97.00    3438.0    4705        1.0            0
# S1129520203  300.50       3.0       5        5.0            0

# %%
fd_df_opp.dtypes
# Out:
# Sport               object
# Date        datetime64[ns]
# Title               object
# Score              float64
# Position           float64
# Opponent            object
# Entry              float64
# Winnings            object
# dtype: object

# %%
fd_df.dtypes
# Out:
# Date        datetime64[ns]
# Score              float64
# Entries            float64
# Entry              float64
# Winnings           float64
# Profit             float64
# Sport               object
# Type                object
# dtype: object

# %%
fd_df.Entries = fd_df.Entries.astype('float64')

# %%
fd_df_opp.Winnings = fd_df_opp.Winnings.astype('float64')
# Out:
# /Users/andrewtriola/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fd_df.Winnings = fd_df.Winnings.astype('float64')

# %%
fd_df.sort_values(by='Winnings', ascending=False).head(20)
# Out:
#             Sport       Date  \
# Entry Id
# S1158884398   nba 2017-02-06
# S1528688111   cfb 2018-09-22
# S1340593093   nba 2017-11-28
# S1147802620   epl 2017-01-21
# S1153192593   nba 2017-01-28
# S1569747022   cfb 2018-10-27
# S438810178    nba 2016-03-13
# S1921160270   nba 2019-12-16
# S438809452    nba 2016-03-13
# S1462010933   mlb 2018-05-10
# S1018072057   nfl 2016-09-18
# S1103758566   nfl 2016-12-11
# S1780016729   mlb 2019-08-29
# S501400144    mlb 2016-06-25
# S1489655846  fifa 2018-07-07
# S455401941    nba 2016-04-03
# S438809813    nba 2016-03-13
# S1365859684   nfl 2017-12-24
# S1062457381   nfl 2016-11-06
# S1041897527   nfl 2016-10-16
#
#                                                         Title   Score  \
# Entry Id
# S1158884398                 $25K Mon NBA Swat (3 Entries Max)  413.40
# S1528688111                            $8K Sat CFB Fight Song  168.34
# S1340593093                 $10K Tue NBA Swat (3 Entries Max)  380.40
# ...

# %%
fd_df['Profit'] = fd_df['Winnings'] - fd_df['Entry']

# %%
fd_df_opp['Profit'] = fd_df_opp['Winnings'] - fd_df_opp['Entry']
# Out:
# /Users/andrewtriola/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fd_df_opp[fd_df_opp['Opponent']=='nwalker2'].sum()
# Out:
# Sport       eplnfleplnbanbaeplucleplepleplepleplepleplnfle...
# Title       EPL Head-to-head (Main)NFL Head-to-head (Main)...
# Score                                                 4059.09
# Position                                                   38
# Opponent    nwalker2nwalker2nwalker2nwalker2nwalker2nwalke...
# Entry                                                     129
# Winnings                                                102.6
# Profit                                                  -26.4
# dtype: object

# %%
fd_df.Profit.sum()
# Out:
# 3791.23

# %%
fd_df.Sport.value_counts()
# Out:
# nba      5308
# mlb      4242
# nfl      2634
# other    1516
# Name: Sport, dtype: int64

# %%
col_list3 = ['cfb', 'cbb', 'epl', 'nhl', 'fifa', 'ucl', 'soc', 'pga', 'wnba', 'xfl', 'nascar']

# %%
fd_df['Sport'] = ['other' if x in col_list3 else x for x in fd_df['Sport']]

# %%
fd_df.Sport.value_counts()
# Out:
# nba      5308
# mlb      4242
# nfl      2634
# other    1516
# Name: Sport, dtype: int64

# %%
fd_df.groupby(['Sport']).sum()
# Out:
#              Score    Position     Entries     Entry  Winnings   Profit
# Sport
# cbb       60205.60    475056.0   1051246.0    966.10    589.10  -377.00
# cfb       88499.19    555935.0   1151345.0   1916.43   2941.02  1024.59
# epl       31334.60    202238.0    482190.0    578.25    992.05   413.80
# fifa       7769.00     92307.0    167354.0    175.25    292.00   116.75
# mlb      523037.55  12910164.0  28796873.0   9153.09   8114.66 -1038.43
# nascar      626.40      8865.0     15135.0      0.00      0.00     0.00
# nba     1532964.21  36520175.0  83441520.0  12679.32  14574.36  1895.04
# nfl      323857.02  22503232.0  55661857.0   9616.94  11336.39  1719.45
# nhl        7894.75    237695.0    557574.0    136.44    105.60   -30.84
# pga        6276.90     77991.0    183668.0     12.25      2.00   -10.25
# soc        4321.50      4482.0     18335.0     70.00    135.20    65.20
# ucl        6748.76     21772.0     45760.0     84.00    100.67    16.67
# ...

# %%
fd_df = fd_df.drop(columns=['Title', 'Position'])

# %%
fd_df.columns
# Out:
# Index(['Date', 'Score', 'Entries', 'Entry', 'Winnings', 'Profit', 'Sport',
#        'Type'],
#       dtype='object')

# %%
col_list = ['Date', 'Score', 'Entries', 'Entry ($)', 'Winnings ($)', 'Sport', 'Type']

# %%
col_list2 = ['Date', 'Score', 'Entries', 'Entry', 'Winnings', 'Profit', 'Sport', 'Type']

# %%
fd_df = fd_df[col_list2]

# %%
fd_df.head()
# Out:
#                   Date   Score   Entries  Entry  Winnings  Profit Sport  \
# Entry Id
# S1124007655 2017-01-01  135.20    5042.0    7.0       0.0    -7.0   nfl
# S1129890321 2017-01-01   82.88  110080.0    2.0       0.0    -2.0   nfl
# S1129826425 2017-01-01  111.50       4.0    5.0       0.0    -5.0   nfl
# S1129544973 2017-01-01   97.00    4705.0    1.0       0.0    -1.0   nfl
# S1129520203 2017-01-01  300.50       5.0    5.0       0.0    -5.0   nba
#
#                 Type
# Entry Id
# S1124007655  tourney
# S1129890321  tourney
# S1129826425  tourney
# S1129544973  tourney
# S1129520203  tourney

# %%
fd_df['Winnings ($)'].value_counts()
# Out:
# 0.0     5553
# 0       3637
# 3.6      753
# 1.8      495
# 9.0      446
#         ...
# 4.57       1
# 6.15       1
# 2.7        1
# 1.33       1
# 2.22       1
# Name: Winnings ($), Length: 232, dtype: int64

# %%
fd_dummies = pd.get_dummies(fd_df, drop_first=True)

# %%
fd_dummies.head()
# Out:
#                   Date   Score   Entries  Entry  Winnings  Profit  Sport_nba  \
# Entry Id
# S1124007655 2017-01-01  135.20    5042.0    7.0       0.0    -7.0          0
# S1129890321 2017-01-01   82.88  110080.0    2.0       0.0    -2.0          0
# S1129826425 2017-01-01  111.50       4.0    5.0       0.0    -5.0          0
# S1129544973 2017-01-01   97.00    4705.0    1.0       0.0    -1.0          0
# S1129520203 2017-01-01  300.50       5.0    5.0       0.0    -5.0          1
#
#              Sport_nfl  Sport_other  Type_tourney
# Entry Id
# S1124007655          1            0             1
# S1129890321          1            0             1
# S1129826425          1            0             1
# S1129544973          1            0             1
# S1129520203          0            0             1

# %%
fd_dummies.shape
# Out:
# (13700, 10)

# %%
fd_corr = fd_dummies.corr()

# %%
fd_corr.head()
# Out:
#              Score   Entries     Entry  Winnings    Profit  Sport_nba  \
# Score     1.000000  0.034068 -0.020938  0.057686  0.062156   0.886533
# Entries   0.034068  1.000000 -0.124766 -0.023285 -0.001026   0.087950
# Entry    -0.020938 -0.124766  1.000000  0.154880 -0.023905  -0.042934
# Winnings  0.057686 -0.023285  0.154880  1.000000  0.983949  -0.004505
# Profit    0.062156 -0.001026 -0.023905  0.983949  1.000000   0.003196
#
#           Sport_nfl  Sport_other  Type_tourney
# Score     -0.363428    -0.188789     -0.226669
# Entries    0.145538    -0.122789      0.246764
# Entry      0.144349     0.001813     -0.272115
# Winnings   0.034843     0.009482     -0.043037
# Profit     0.009185     0.009268      0.005602

# %%
plt.figure(figsize=(20,10))
sns.heatmap(fd_corr, annot=True, fmt='.1g', cmap= 'coolwarm')

# %%
fd_df_2 = fd_dummies.drop(columns=['Score'])

# %%
fd_df_2.head()
# Out:
#                   Date   Entries  Entry  Winnings  Profit  Sport_nba  \
# Entry Id
# S1124007655 2017-01-01    5042.0    7.0       0.0    -7.0          0
# S1129890321 2017-01-01  110080.0    2.0       0.0    -2.0          0
# S1129826425 2017-01-01       4.0    5.0       0.0    -5.0          0
# S1129544973 2017-01-01    4705.0    1.0       0.0    -1.0          0
# S1129520203 2017-01-01       5.0    5.0       0.0    -5.0          1
#
#              Sport_nfl  Sport_other  Type_tourney
# Entry Id
# S1124007655          1            0             1
# S1129890321          1            0             1
# S1129826425          1            0             1
# S1129544973          1            0             1
# S1129520203          0            0             1

# %%
fd_corr2 = fd_df_2.corr()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(fd_corr2, annot=True, fmt='.1g', cmap= 'coolwarm')

# %%
fd_reg_simple = ols(formula= "Profit~Entry+Sport_nba+Sport_nfl+Sport_other+Type_tourney", data=fd_df_2).fit()
fd_reg_simple.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.877
# Date:                Sun, 10 May 2020   Prob (F-statistic):             0.0134
# Time:                        09:38:41   Log-Likelihood:                -60457.
# No. Observations:               13700   AIC:                         1.209e+05
# Df Residuals:                   13694   BIC:                         1.210e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
fd_reg_simple2 = ols(formula= "Profit~Entry", data=fd_df_2).fit()
fd_reg_simple2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     7.832
# Date:                Sun, 10 May 2020   Prob (F-statistic):            0.00514
# Time:                        10:46:50   Log-Likelihood:                -60460.
# No. Observations:               13700   AIC:                         1.209e+05
# Df Residuals:                   13698   BIC:                         1.209e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6186      0.210      2.948      0.003       0.207       1.030
# ...

# %%
### from title column break down contests into different types

# %%
fd_df['Type'] = np.nan

# %%
fd_df.head()
# Out:
#                   Date   Score   Entries  Entry  Winnings  Profit Sport  \
# Entry Id
# S1124007655 2017-01-01  135.20    5042.0    7.0       0.0    -7.0   nfl
# S1129890321 2017-01-01   82.88  110080.0    2.0       0.0    -2.0   nfl
# S1129826425 2017-01-01  111.50       4.0    5.0       0.0    -5.0   nfl
# S1129544973 2017-01-01   97.00    4705.0    1.0       0.0    -1.0   nfl
# S1129520203 2017-01-01  300.50       5.0    5.0       0.0    -5.0   nba
#
#                 Type
# Entry Id
# S1124007655  tourney
# S1129890321  tourney
# S1129826425  tourney
# S1129544973  tourney
# S1129520203  tourney

# %%
#df['Price'] = [1500 if x =='Music' else 800 for x in df['Event']]

# %%
fd_df['Type'] = ['fifty' if x.startswith('50') == True else 'tourney' for x in fd_df['Title']]

# %%
fd_df.Entry.sum()
# Out:
# 35394.07

# %%
fd_df.Type.value_counts()
# Out:
# tourney    10321
# fifty       3379
# Name: Type, dtype: int64

# %%
fd_df.head()
# Out:
#             Sport       Date   Score Entries  Entry ($) Winnings ($)     Type
# Entry Id
# S1124007655   nfl 2017-01-01  135.20    5042        7.0            0  tourney
# S1129890321   nfl 2017-01-01   82.88  110080        2.0            0  tourney
# S1129826425   nfl 2017-01-01  111.50       4        5.0            0  tourney
# S1129544973   nfl 2017-01-01   97.00    4705        1.0            0  tourney
# S1129520203   nba 2017-01-01  300.50       5        5.0            0  tourney

# %%
# import statsmodels.api as sm
# from statsmodels.graphics.regressionplots import abline_plot

# # regress "expression" onto "motifScore" (plus an intercept)
# model = sm.OLS(motif.expression, sm.add_constant(motif.motifScore))

# # scatter-plot data
# ax = motif.plot(x='motifScore', y='expression', kind='scatter')

# # plot regression line
# abline_plot(model_results=model.fit(), ax=ax)

# %%
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import abline_plot

# %%
fd_reg_simple

# %%
ax = fd_df.plot(x='Date', y='Profit', kind='scatter')
abline_plot(model_results=fd_reg_simple2, ax=ax)

# %%
abline_plot(model_results=fd_reg_simple4)

# %%
fd_reg_simple3 = ols(formula= "Profit~Sport_nba+Sport_nfl+Sport_other", data=fd_df_2).fit()
fd_reg_simple3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.653
# Date:                Sun, 10 May 2020   Prob (F-statistic):              0.175
# Time:                        10:39:01   Log-Likelihood:                -60462.
# No. Observations:               13700   AIC:                         1.209e+05
# Df Residuals:                   13696   BIC:                         1.210e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.2448      0.307     -0.798      0.425      -0.846       0.356
# ...

# %%
fd_reg_simple4 = ols(formula= "Profit~Type_tourney", data=fd_df_2).fit()
fd_reg_simple4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.4299
# Date:                Sun, 10 May 2020   Prob (F-statistic):              0.512
# Time:                        10:39:28   Log-Likelihood:                -60464.
# No. Observations:               13700   AIC:                         1.209e+05
# Df Residuals:                   13698   BIC:                         1.209e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
fd_df_new = result[col_list].copy()

# %%
fd_df_new = fd_df_new.dropna()

# %%
fd_df_new.head()
# Out:
#             Sport     Date                                     Title  Score  \
# Entry Id
# S2014268241   nba  3/11/20  $4_000 Pro Monthly FDP Loyalty Free Play  337.5
# S2014175433   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175293   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175208   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175131   nba  3/11/20    50/50 League ($2 - Top 50% Win) (Main)  337.5
#
#              Position Entries  Entry ($) Winnings ($)
# Entry Id
# S2014268241     100.0    5092        0.0            8
# S2014175433       7.0     100        1.0          1.8
# S2014175293       6.0     100        1.0          1.8
# S2014175208       8.0     100        1.0          1.8
# S2014175131       6.0     100        2.0          3.6

# %%
fd_df_new = fd_df_new.rename(columns={"Entry ($)": "Entry", "Winnings ($)": "Winnings"})

# %%
fd_df_new.head()
# Out:
#             Sport     Date                                     Title  Score  \
# Entry Id
# S2014268241   nba  3/11/20  $4_000 Pro Monthly FDP Loyalty Free Play  337.5
# S2014175433   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175293   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175208   nba  3/11/20    50/50 League ($1 - Top 50% Win) (Main)  337.5
# S2014175131   nba  3/11/20    50/50 League ($2 - Top 50% Win) (Main)  337.5
#
#              Position Entries  Entry Winnings
# Entry Id
# S2014268241     100.0    5092    0.0        8
# S2014175433       7.0     100    1.0      1.8
# S2014175293       6.0     100    1.0      1.8
# S2014175208       8.0     100    1.0      1.8
# S2014175131       6.0     100    2.0      3.6

# %%
fd_df_new = fd_df_new.sort_values(by='Date')

# %%
fd_df_new.Date.value_counts()
# Out:
# 12/1/19     112
# 12/22/19    102
# 11/17/19     87
# 11/3/19      84
# 12/8/19      77
#            ...
# 1/21/19       1
# 10/4/18       1
# 11/2/17       1
# 10/12/18      1
# 10/17/17      1
# Name: Date, Length: 1246, dtype: int64

# %%
fd_df_new.Date = pd.to_datetime(fd_df_new.Date, infer_datetime_format=True)

# %%
fd_df_new.Entries = fd_df_new.Entries.astype('float64')

# %%
fd_df_new.Winnings = fd_df_new.Winnings.astype('float64')

# %%
fd_df_new.dtypes
# Out:
# Sport               object
# Date        datetime64[ns]
# Title               object
# Score              float64
# Position           float64
# Entries            float64
# Entry              float64
# Winnings           float64
# dtype: object

# %%
fd_df_new['Profit'] = fd_df_new['Winnings'] - fd_df_new['Entry']

# %%
cond1 = fd_df_new['Sport'] != 'nba'

# %%
cond2 = fd_df_new['Sport'] != 'nfl'

# %%
cond3 = fd_df_new['Sport'] != 'mlb'

# %%
fd_df_other = fd_df_new[(cond1) & (cond2) & (cond3)]

# %%
fd_df_other.head()
# Out:
#             Sport       Date                                       Title  \
# Entry Id
# S1648200068   epl 2019-01-01     $500 Tue EPL Corner Kick (Single Entry)
# S1648200130   epl 2019-01-01       $400 Tue EPL Equalizer (Single Entry)
# S1648494695   cfb 2019-01-01  $3K Tue CFB Helmet Sticker (3 Entries Max)
# S1648496522   cbb 2019-01-01       $500 Tue CBB Bank Shot (Single Entry)
# S1648495553   cfb 2019-01-01  $500 Tue CFB Helmet Sticker (Single Entry)
#
#               Score  Position  Entries  Entry  Winnings  Profit
# Entry Id
# S1648200068  127.50     196.0    297.0    2.0       0.0    -2.0
# S1648200130  105.50     426.0    476.0    1.0       0.0    -1.0
# S1648494695  106.14     515.0   3571.0    1.0       2.0     1.0
# S1648496522  180.50      51.0    297.0    2.0       4.0     2.0
# S1648495553   65.02     521.0    595.0    1.0       0.0    -1.0

# %%
fd_df_other['Type'] = np.nan
# Out:
# /Users/andrewtriola/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fd_df_other.head(25)
# Out:
#                   Date   Score  Entries  Entry  Winnings  Profit Sport  \
# Entry Id
# S1648200068 2019-01-01  127.50    297.0    2.0       0.0    -2.0   epl
# S1648200130 2019-01-01  105.50    476.0    1.0       0.0    -1.0   epl
# S1648494695 2019-01-01  106.14   3571.0    1.0       2.0     1.0   cfb
# S1648496522 2019-01-01  180.50    297.0    2.0       4.0     2.0   cbb
# S1648495553 2019-01-01   65.02    595.0    1.0       0.0    -1.0   cfb
# S1648495007 2019-01-01   79.10   3306.0    9.0       0.0    -9.0   cfb
# S1648494927 2019-01-01   99.34   3571.0    1.0       0.0    -1.0   cfb
# S1648494890 2019-01-01  107.30   3571.0    1.0       2.0     1.0   cfb
# S1942481226 2020-01-01  172.00    714.0    1.0       6.0     5.0   epl
# S1942481318 2020-01-01  159.40    297.0    2.0       6.0     4.0   epl
# S1656621605 2019-01-10  163.60    543.0    2.0       0.0    -2.0   cbb
# S1953662033 2020-01-10  161.80    148.0    2.0       0.0    -2.0   cbb
# ...

# %%
fd_df_other['Type'] = ['fifty' if x.startswith('50') == True else 'tourney' for x in fd_df_other['Title']]
# Out:
# /Users/andrewtriola/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fd_df_other = fd_df_other[col_list2]

# %%
fd_od = pd.get_dummies(fd_df_other, drop_first=True)

# %%
fd_od.head()
# Out:
#                   Date   Score  Entries  Entry  Winnings  Profit  Sport_cfb  \
# Entry Id
# S1648200068 2019-01-01  127.50    297.0    2.0       0.0    -2.0          0
# S1648200130 2019-01-01  105.50    476.0    1.0       0.0    -1.0          0
# S1648494695 2019-01-01  106.14   3571.0    1.0       2.0     1.0          1
# S1648496522 2019-01-01  180.50    297.0    2.0       4.0     2.0          0
# S1648495553 2019-01-01   65.02    595.0    1.0       0.0    -1.0          1
#
#              Sport_epl  Sport_fifa  Sport_nascar  Sport_nhl  Sport_pga  \
# Entry Id
# S1648200068          1           0             0          0          0
# S1648200130          1           0             0          0          0
# S1648494695          0           0             0          0          0
# S1648496522          0           0             0          0          0
# S1648495553          0           0             0          0          0
#
# ...

# %%
od_corr = fd_od.corr()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(od_corr, annot=True, fmt='.1g', cmap= 'coolwarm')

# %%
fd_df_other.Sport.value_counts()
# Out:
# cfb       745
# cbb       300
# epl       215
# nhl        79
# fifa       70
# ucl        52
# soc        22
# pga        19
# wnba        7
# xfl         4
# nascar      3
# Name: Sport, dtype: int64

# %%
fd_od_2 = fd_od.drop(columns=['Score'])

# %%
fd_od_2.head()
# Out:
#                   Date  Entries  Entry  Winnings  Profit  Sport_cfb  \
# Entry Id
# S1648200068 2019-01-01    297.0    2.0       0.0    -2.0          0
# S1648200130 2019-01-01    476.0    1.0       0.0    -1.0          0
# S1648494695 2019-01-01   3571.0    1.0       2.0     1.0          1
# S1648496522 2019-01-01    297.0    2.0       4.0     2.0          0
# S1648495553 2019-01-01    595.0    1.0       0.0    -1.0          1
#
#              Sport_epl  Sport_fifa  Sport_nascar  Sport_nhl  Sport_pga  \
# Entry Id
# S1648200068          1           0             0          0          0
# S1648200130          1           0             0          0          0
# S1648494695          0           0             0          0          0
# S1648496522          0           0             0          0          0
# S1648495553          0           0             0          0          0
#
#              Sport_soc  Sport_ucl  Sport_wnba  Sport_xfl  Type_tourney
# Entry Id
# ...

# %%
od_corr_2 = fd_od_2.corr()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(od_corr_2, annot=True, fmt='.1g', cmap= 'coolwarm')

# %%
other_reg = ols(formula= "Profit~Sport_cfb+Sport_epl+Sport_nhl+Sport_ucl+Sport_fifa", data=fd_od_2).fit()
other_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.3751
# Date:                Sun, 17 May 2020   Prob (F-statistic):              0.866
# Time:                        10:57:48   Log-Likelihood:                -7328.5
# No. Observations:                1516   AIC:                         1.467e+04
# Df Residuals:                    1510   BIC:                         1.470e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9177      1.618     -0.567      0.571      -4.091       2.256
# ...

# %%
other_reg_2 = ols(formula= "Profit~Type_tourney", data=fd_od_4).fit()
other_reg_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.08534
# Date:                Sun, 17 May 2020   Prob (F-statistic):              0.770
# Time:                        12:03:11   Log-Likelihood:                -7309.7
# No. Observations:                1514   AIC:                         1.462e+04
# Df Residuals:                    1512   BIC:                         1.463e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
abline_plot(model_results=other_reg_2)

# %%
other_reg_3 = ols(formula= "Profit~Entry+Type_tourney", data=fd_od_4).fit()
other_reg_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1109
# Date:                Sun, 17 May 2020   Prob (F-statistic):              0.895
# Time:                        12:03:28   Log-Likelihood:                -7309.6
# No. Observations:                1514   AIC:                         1.463e+04
# Df Residuals:                    1511   BIC:                         1.464e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
abline_plot(model_results=other_reg_3)

# %%
ax1 = fd_od_2[fd_od_2['Entry'] < 100].plot(kind='scatter', x='Entry', y='Winnings', color='blue', alpha=0.5, figsize=(10, 7))

# %%
cond4 = fd_od_2.Entry < 100

# %%
cond5 = fd_od_2.Winnings < 100

# %%
fd_od_3 = fd_od_2[(cond4) & (cond5)]

# %%
fd_od_4 = fd_od_2[(cond4)]

# %%
fd_od_3.head()
# Out:
#                   Date  Entries  Entry  Winnings  Profit  Sport_cfb  \
# Entry Id
# S1648200068 2019-01-01    297.0    2.0       0.0    -2.0          0
# S1648200130 2019-01-01    476.0    1.0       0.0    -1.0          0
# S1648494695 2019-01-01   3571.0    1.0       2.0     1.0          1
# S1648496522 2019-01-01    297.0    2.0       4.0     2.0          0
# S1648495553 2019-01-01    595.0    1.0       0.0    -1.0          1
#
#              Sport_epl  Sport_fifa  Sport_nascar  Sport_nhl  Sport_pga  \
# Entry Id
# S1648200068          1           0             0          0          0
# S1648200130          1           0             0          0          0
# S1648494695          0           0             0          0          0
# S1648496522          0           0             0          0          0
# S1648495553          0           0             0          0          0
#
#              Sport_soc  Sport_ucl  Sport_wnba  Sport_xfl  Type_tourney
# Entry Id
# ...

# %%
fd_od_3.Profit.sum()
# Out:
# -522.8299999999999

# %%
fd_od_2.Profit.sum()
# Out:
# 1215.17

# %%
other_a = ols(formula= "Profit~Sport_cfb+Sport_epl+Sport_nhl+Sport_ucl+Sport_fifa", data=fd_od_4).fit()
other_a.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2485
# Date:                Sun, 17 May 2020   Prob (F-statistic):              0.941
# Time:                        12:04:52   Log-Likelihood:                -7309.1
# No. Observations:                1514   AIC:                         1.463e+04
# Df Residuals:                    1508   BIC:                         1.466e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3564      1.612     -0.221      0.825      -3.518       2.806
# ...

# %%
cond6 = fd_od_2.Winnings > 100

# %%
fd_od_2[(cond6)]
# Out:
#                   Date  Entries  Entry  Winnings  Profit  Sport_cfb  \
# Entry Id
# S1147802620 2017-01-21   6274.0    3.0     500.0   497.0          0
# S1569747022 2018-10-27   1488.0    4.0     300.0   296.0          1
# S1489655846 2018-07-07   2976.0    1.0     150.0   149.0          0
# S1528688111 2018-09-22   2210.0    4.0    1000.0   996.0          1
#
#              Sport_epl  Sport_fifa  Sport_nascar  Sport_nhl  Sport_pga  \
# Entry Id
# S1147802620          1           0             0          0          0
# S1569747022          0           0             0          0          0
# S1489655846          0           1             0          0          0
# S1528688111          0           0             0          0          0
#
#              Sport_soc  Sport_ucl  Sport_wnba  Sport_xfl  Type_tourney
# Entry Id
# S1147802620          0          0           0          0             1
# S1569747022          0          0           0          0             1
# ...
